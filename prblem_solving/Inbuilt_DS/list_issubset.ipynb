# %%
print('hello world')
# Out:
# hello world

# %%
def is_subset(lst1, lst2):
    # Your code goes here
    
    for i in range(len(lst1)):
        found = False
        
        for j in range(len(lst2)):
            if lst1[i]==lst2[i]:
                found = True
                break
        
        if not found:
            return False
        
        
    return True

is_subset(lst1=[1,2,3,],lst2=[1,2,3,4,5])
# Out:
# True
