# %%
print('hello world')
# Out:
# hello world

# %%
### PROBLEM

# %% [markdown]
# #### Reverse the order of words in a sentence. Handle multiple spaces.
# - Input:
# 'hello world java'
# - Output:
# 'java world hello'

# %%
def reverse_string(s):
    return ' '.join(s.split()[::-1])

reverse_string(s='sami is good')
# Out:
# 'good is sami'
